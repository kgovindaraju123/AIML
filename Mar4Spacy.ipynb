# %% [markdown]
# <a href="https://colab.research.google.com/github/kgovindaraju123/AIML/blob/master/Mar4Spacy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#spacy open source library, install spacy models
# !python3 -m spacy download en_core_web_md
# !python3 -m spacy download en_core_web_sm
# Out:
# ...
#      |████████████████████████████████| 95.4MB 4.3MB/s
# ...
#   Created wheel for en-core-web-md: filename=en_core_web_md-2.1.0-cp36-none-any.whl size=97126236 sha256=d98a129aa45fc7cbae8c4520d99688d1315e26231fa14f80697cc1389be172df
#   Stored in directory: /tmp/pip-ephem-wheel-cache-96iyxhka/wheels/c1/2c/5f/fd7f3ec336bf97b0809c86264d2831c5dfb00fc2e239d1bb01
# Successfully built en-core-web-md
# ...
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_md')
# ...
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')

# %%
import spacy
nlp=spacy.load("en_core_web_sm") #pretrained model
doc=nlp("Apple is looking at buying U.K. startup for $1 Billion")
for token in doc:
  print(token.text,token.pos_,token.dep_)
# Out:
# Apple PROPN nsubj
# is VERB aux
# looking VERB ROOT
# at ADP prep
# buying VERB pcomp
# U.K. PROPN compound
# startup NOUN dobj
# for ADP prep
# $ SYM quantmod
# 1 NUM compound
# Billion NUM pobj

# %%
#tokenization
import spacy
nlp=spacy.load("en_core_web_sm")
doc=nlp("Apple is looking at buying U.K. startup for $1 Billion")
for token in doc:
  print(token.text)
# Out:
# Apple
# is
# looking
# at
# buying
# U.K.
# startup
# for
# $
# 1
# Billion

# %%
#POS parts of speech
import spacy
from spacy import displacy
nlp=spacy.load("en_core_web_sm")
doc=nlp ("Apple is looking at buying U.K. startup for $1 Billion")
#displacy.serve(doc, style="dep")
for token in doc: print(token.text,token.lemma_,token.pos,token.tag_,token.dep_,token.shape,token.is_alpha,token.is_stop)
# Out:
# Apple Apple 96 NNP nsubj 16072095006890171862 True False
# is be 100 VBZ aux 4370460163704169311 True True
# looking look 100 VBG ROOT 13110060611322374290 True False
# at at 85 IN prep 4370460163704169311 True True
# buying buy 100 VBG pcomp 13110060611322374290 True False
# U.K. U.K. 96 NNP compound 9346084826459880894 False False
# startup startup 92 NN dobj 13110060611322374290 True False
# for for 85 IN prep 4088098365541558500 True True
# $ $ 99 $ quantmod 11283501755624150392 False False
# 1 1 93 CD compound 8148669997605808657 False False
# Billion billion 93 CD pobj 16072095006890171862 True False

# %%
#visulaizers
import spacy
from spacy import displacy
nlp =spacy.load("en_core_web_sm")
doc=nlp("This is a sentence.")
displacy.render(doc,style='dep',jupyter=True, options={'distance':90})
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="a7540990927f4f968f98096ffeb0a896-0" class="displacy" width="410" height="227.0" direction="ltr" style="max-width: none; height: 227.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="137.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">This</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="137.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="137.0">
#     <tspan class="displacy-word" fill="currentColor" x="230">a</tspan>
# ...

# %%
import spacy 
from spacy import displacy
nlp=spacy.load("en_core_web_sm")
text="""In ancient Rome, some neighbors live in three adjacent houses. In the center is the house of Senex, who lives there with wife Domina, son Hero, and several slaves, including head slave Hysterium and the musical's main character Pseudolus. A slave belonging to Hero, Pseudolus wishes to buy, win, or steal his freedom. One of the neighboring houses is owned by Marcus Lycus, who is a buyer and seller of beautiful women; the other belongs to the ancient Erronius, who is abroad searching for his long-lost children (stolen in infancy by pirates). One day, Senex and Domina go on a trip and leave Pseudolus in charge of Hero. Hero confides in Pseudolus 
that he is in love with the lovely Philia, one of the courtesans in the House of Lycus (albeit still a virgin)."""
doc=nlp(text)
sentence_spans=list(doc.sents)
displacy.render(doc,style ='dep',jupyter=True, options={'distance':90})
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="a731b27af2394f059ee98518d4103814-0" class="displacy" width="12380" height="497.0" direction="ltr" style="max-width: none; height: 497.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">In</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">ancient</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="230">Rome,</tspan>
# ...

# %%
#Named entity recognition
import spacy 
from spacy import displacy 
import en_core_web_sm
nlp = spacy.load("en_core_web_sm")
doc=nlp("Apple is looking at buying U.K. startup for $1 Billion")
for ent in doc.ents:
  print(ent.text,ent.start_char,ent.end_char,ent.label_)
  displacy.render(doc,style='ent',jupyter=True,options={'distance':90})
# Out:
# Apple 0 5 ORG
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is looking at buying
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     U.K.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  startup for
# ...

# %%
#Similarity
import spacy
import en_core_web_md
nlp = spacy.load("en_core_web_md")
tokens=nlp("dog cat banana asdfdfsd")
for token in tokens:
  print(token.text,token.has_vector,token.vector_norm,token.is_oov) #out of vector
# Out:
# dog True 7.0336733 False
# cat True 6.6808186 False
# banana True 6.700014 False
# asdfdfsd False 0.0 True

# %%
#Similarity
import spacy
import en_core_web_md
nlp = spacy.load("en_core_web_md")
tokens=nlp("dog cat banana")
for token1 in tokens:
  for token2 in tokens:
    print(token1.text,token2.text,token1.similarity(token2))
# Out:
# dog dog 1.0
# dog cat 0.80168545
# dog banana 0.24327643
# cat dog 0.80168545
# cat cat 1.0
# cat banana 0.28154364
# banana dog 0.24327643
# banana cat 0.28154364
# banana banana 1.0

# %%
#Hash Strings
import spacy
import en_core_web_sm
nlp = spacy.load("en_core_web_sm")
tokens=nlp("I love coffee")
for word in tokens:
  lexeme=doc.vocab[word.text]
  print(lexeme.text,lexeme.orth,lexeme.shape_,lexeme.prefix_,lexeme.suffix_,lexeme.is_alpha,lexeme.is_digit,lexeme.is_title,lexeme.lang_)
# Out:
# I 4690420944186131903 X I I True False True en
# love 3702023516439754181 xxxx l ove True False False en
# coffee 3197928453018144401 xxxx c fee True False False en
